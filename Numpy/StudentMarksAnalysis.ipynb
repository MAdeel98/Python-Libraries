# %% [markdown]
# Tasks
#
# Find total marks of every student.
# Find average marks.
# Highest scorer.
# Lowest scorer.
# Average marks of each subject.
# Students scoring above 80 average.
# Replace marks below 60 with 60 (grace marks).
# Add a fourth subject.

# %%
import numpy as np

# %%
marks = np.array([
    [78, 82, 91],
    [56, 61, 70],
    [90, 88, 95],
    [57, 56, 65],
    [85, 90, 89]
])

# %%
total=np.sum(marks[:,:],axis=1)

# %%
total
# Out:
# array([251, 187, 273, 204, 264])

# %%
# Find average marks.

# %%
average=np.mean(marks[:,:],axis=1)

# %%
average
# Out:
# array([83.66666667, 62.33333333, 91.        , 68.        , 88.        ])

# %% [markdown]
# higestscorer

# %%
high_scorer=total.max()

# %%
high_scorer
# Out:
# np.int64(273)

# %%
low_score=total.min()

# %%
low_score
# Out:
# np.int64(187)

# %%
# marks.mean()
#overall avg marks
# Out:
# np.float64(78.6)

# %%
# Students scoring above 80 average.
for i in average:
    if i > 80:
        print(i)
# Out:
# 83.66666666666667
# 91.0
# 88.0

# %% [markdown]
# Replace marks below 60 with 60 (grace marks).

# %%
marks
# Out:
# array([[78, 82, 91],
#        [56, 61, 70],
#        [90, 88, 95],
#        [67, 72, 65],
#        [85, 90, 89]])

# %%
# marks=marks[ marks<60 ]=60
# marks

marks[:,:][marks[:,:] <60]=60

# %%
marks #i have reassighned value here for grace marks , so above result may vary if you run all the cell combine ....
# Out:
# array([[78, 82, 91],
#        [60, 61, 70],
#        [90, 88, 95],
#        [60, 60, 65],
#        [85, 90, 89]])

# %%
# fourth subject we have to add there 
fourthsub=np.array([87,54,76,87,90])

# %%
updated=np.column_stack((marks,fourthsub))
marks=updated

# %%
marks
# Out:
# array([[78, 82, 91, 87],
#        [60, 61, 70, 54],
#        [90, 88, 95, 76],
#        [60, 60, 65, 87],
#        [85, 90, 89, 90]])
