# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
[df.groupby('Sex')['Survived'].mean]
# Out:
# [<bound method GroupBy.mean of <pandas.api.typing.SeriesGroupBy object at 0x0000028DED17A570>>]

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().idxmax()
# Out:
# np.int64(3)

# %%
df[(df['Age']>35) & (df['Age']<42)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 13            14         0       3
# 25            26         1       3
# 30            31         0       1
# 40            41         0       3
# ..           ...       ...     ...
# 811          812         0       3
# 822          823         0       1
# 835          836         1       1
# 860          861         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(['Cabin'],axis=1,inplace=True)

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df.info()
# df.groupby('Sex')["Survival"].sum()
df['Sex'].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    str
# dtypes: float64(2), int64(5), str(4)
# memory usage: 76.7 KB
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.groupby('Sex')['Fare'].max()
# Out:
# Sex
# female    512.3292
# male      512.3292
# Name: Fare, dtype: float64

# %%
df[df['Fare']==df['Fare'].max()]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# 258  female  35.0      0      0  PC 17755  512.3292        C
# 679    male  36.0      0      1  PC 17755  512.3292        C
# 737    male  35.0      0      0  PC 17755  512.3292        C

# %%
df[(df["Pclass"]==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sub=df[(df['Survived']==1) & (df['Pclass']==1) & (df['SibSp']==1)]
sub
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 52            53         1       1
# 151          152         1       1
# 215          216         1       1
# 224          225         1       1
# 230          231         1       1
# 248          249         1       1
# 275          276         1       1
# 291          292         1       1
# 305          306         1       1
# 307          308         1       1
# 319          320         1       1
# 334          335         1       1
# 366          367         1       1
# 370          371         1       1
# 375          376         1       1
# 383          384         1       1
# 390          391         1       1
# 393          394         1       1
# 412          413         1       1
# 435          436         1       1
# 453          454         1       1
# 457          458         1       1
# ...

# %%
sub.shape
# Out:
# (53, 11)

# %%
df[(df['Survived']==1)  & (df['SibSp']==1)]['Sex'].value_counts()
# Out:
# Sex
# female    80
# male      32
# Name: count, dtype: int64

# %%
df[(df['Survived']==1)  & (df['SibSp']==1)].shape
# Out:
# (112, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    str
# dtypes: float64(2), int64(5), str(4)
# memory usage: 76.7 KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.groupby('Pclass')['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
# which gender survived more -----------
df.groupby('Sex')['Survived'].value_counts().unstack()
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
# percentage of survival
df.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
df.groupby('Age')['Survived'].mean()
# Out:
# Age
# 0.42     1.0
# 0.67     1.0
# 0.75     1.0
# 0.83     1.0
# 0.92     1.0
#         ...
# 70.00    0.0
# 70.50    0.0
# 71.00    0.0
# 74.00    0.0
# 80.00    1.0
# Name: Survived, Length: 89, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    str
# dtypes: float64(2), int64(5), str(4)
# memory usage: 76.7 KB

# %%
df.groupby('Embarked')['Sex'].value_counts().unstack()
# Out:
# Sex       female  male
# Embarked
# C             73    95
# Q             36    41
# S            205   441

# %%
# Average fare by class
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# Survival rate by class
df.groupby('Pclass')['Survived'].value_counts().unstack()
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
df.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
# Passenger count by class and gender
df.groupby('Sex')['Pclass'].value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: count, dtype: int64

# %%
df.groupby('Pclass')['Sex'].value_counts().unstack()
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
# Average age by class and gender
df.groupby(['Pclass','Sex'])['Age'].mean()
# Out:
# Pclass  Sex
# 1       female    34.141405
#         male      39.287717
# 2       female    28.748661
#         male      30.653908
# 3       female    24.068493
#         male      27.372153
# Name: Age, dtype: float64

# %%
# Average fare by class
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.nlargest(10,'Fare')
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 258          259         1       1                       Ward, Miss. Anna
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 118          119         0       1               Baxter, Mr. Quigg Edmond
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# 258  female  35.0      0      0  PC 17755  512.3292        C
# ...

# %%
df.sort_values(by='Age',ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Embarked
# 630  male  80.0      0      0     27042  30.0000        S
# 851  male  74.0      0      0    347060   7.7750        S
# 96   male  71.0      0      0  PC 17754  34.6542        C
# 493  male  71.0      0      0  PC 17609  49.5042        C
# 116  male  70.5      0      0    370369   7.7500        Q

# %%
df.sort_values(by='Age',ascending=True).head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Embarked
# 803  0.42      0      1    2625   8.5167        C
# 755  0.67      1      1  250649  14.5000        S
# 469  0.75      2      1    2666  19.2583        C
# 644  0.75      2      1    2666  19.2583        C
# 78   0.83      0      2  248738  29.0000        S

# %%
df.sort_values(by='Name',ascending=True).head()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
#
#         Sex   Age  SibSp  Parch     Ticket   Fare Embarked
# 845    male  42.0      0      0  C.A. 5547   7.55        S
# 746    male  16.0      1      1  C.A. 2673  20.25        S
# 279  female  35.0      1      1  C.A. 2673  20.25        S
# 308    male  30.0      1      0  P/PP 3381  24.00        C
# 874  female  28.0      1      0  P/PP 3381  24.00        C

# %%
# People who paid more than average fare
df[df['Fare']>df['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 6                              McCarthy, Mr. Timothy J    male  54.000000
# 23                        Sloper, Mr. William Thompson    male  28.000000
# 27                      Fortune, Mr. Charles Alexander    male  19.000000
# ..                                                 ...     ...        ...
# ...

# %%
# Third-class passengers older than 40
df[(df['Pclass']==3) & (df['Age']>40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 94            95         0       3
# 116          117         0       3
# 129          130         0       3
# 132          133         0       3
# 152          153         0       3
# 153          154         0       3
# 160          161         0       3
# 167          168         0       3
# 197          198         0       3
# 203          204         0       3
# 222          223         0       3
# 254          255         0       3
# 276          277         0       3
# 280          281         0       3
# 326          327         0       3
# 338          339         1       3
# 349          350         0       3
# 362          363         0       3
# 406          407         0       3
# 414          415         1       3
# 482          483         0       3
# 483          484         1       3
# 525          526         0       3
# 592          593         0       3
# 597          598         0       3
# ...

# %% [markdown]
# ***# Find the top 5 oldest survivors***

# %%
# Find the top 5 oldest survivors
adeel=df.sort_values(by='Age',ascending=False)

# %%
adeel[adeel['Survived']==1].head()
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 570          571         1       2                         Harris, Mr. George
#
#         Sex   Age  SibSp  Parch       Ticket     Fare Embarked
# 630    male  80.0      0      0        27042  30.0000        S
# 275  female  63.0      1      0        13502  77.9583        S
# 483  female  63.0      0      0         4134   9.5875        S
# 829  female  62.0      0      0       113572  80.0000        S
# 570    male  62.0      0      0  S.W./PP 752  10.5000        S

# %%
df[df['Survived']==1].sort_values(by='Age',ascending=False).head(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 570          571         1       2                         Harris, Mr. George
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch       Ticket     Fare Embarked
# 630    male  80.0      0      0        27042  30.0000        S
# 275  female  63.0      1      0        13502  77.9583        S
# 483  female  63.0      0      0         4134   9.5875        S
# 570    male  62.0      0      0  S.W./PP 752  10.5000        S
# 829  female  62.0      0      0       113572  80.0000        S

# %% [markdown]
# ***Find the youngest passenger who did not survive.***

# %%
df[df["Survived"]==0].sort_values(by='Age',ascending=True).head(3)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 386          387         0       3  Goodwin, Master. Sidney Leonard    male
# 642          643         0       3    Skoog, Miss. Margit Elizabeth  female
#
#      Age  SibSp  Parch   Ticket     Fare Embarked
# 164  1.0      4      1  3101295  39.6875        S
# 386  1.0      5      2  CA 2144  46.9000        S
# 642  2.0      3      2   347088  27.9000        S

# %% [markdown]
# ***Count passengers by both class and gender***

# %%
df.groupby(['Pclass'])['Sex'].value_counts()
# Out:
# Pclass  Sex
# 1       male      122
#         female     94
# 2       male      108
#         female     76
# 3       male      347
#         female    144
# Name: count, dtype: int64

# %%
df.groupby(['Pclass'])['Sex'].size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Sex, dtype: int64

# %%
df.pivot_table(index='Pclass',columns='Sex',aggfunc='size')
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347
